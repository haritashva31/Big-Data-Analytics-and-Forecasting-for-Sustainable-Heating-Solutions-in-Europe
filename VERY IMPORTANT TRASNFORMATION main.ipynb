# %%
import pandas as pd
import os
import numpy as np
# Specify the directory where your CSV files are stored
csv_directory = '/Downloads/UNPROCESSED_combined_When2heat_bolnabohotkuch'

# List all CSV files in the directory
csv_files = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]

# Create an empty dictionary to store country-wise DataFrames
country_dfs = {}

# Iterate through CSV files and create DataFrames
for csv_file in csv_files:
    # Extract the country code from the filename (adjust this based on your file naming convention)
    country_code = csv_file.split('_')[0]  # Assuming the country code is at the beginning of the filename

    # Read the CSV file into a DataFrame
    file_path = os.path.join(csv_directory, csv_file)
    country_df = pd.read_csv(file_path)

    # Add the DataFrame to the dictionary
    country_dfs[country_code] = country_df

# %%
country_df.head()
# Out:
#               cet_cest_timestamp  year  month  day  hour  COP_ASHP_floor  \
# 0  2008-01-01T03:30:00.000+05:30  2008      1    1     3             3.0
# 1  2008-01-01T04:30:00.000+05:30  2008      1    1     4             3.0
# 2  2008-01-01T05:30:00.000+05:30  2008      1    1     5             3.0
# 3  2008-01-01T06:30:00.000+05:30  2008      1    1     6             3.0
# 4  2008-01-01T07:30:00.000+05:30  2008      1    1     7             3.0
#
#    COP_ASHP_radiator  COP_ASHP_water  COP_GSHP_floor  COP_GSHP_radiator  ...  \
# 0           2.833333             2.0             4.0                NaN  ...
# 1           2.833333             2.0             4.0                NaN  ...
# 2           2.833333             2.0             4.0                NaN  ...
# 3           2.833333             2.0             4.0                NaN  ...
# 4           2.833333             2.0             4.0                NaN  ...
#
#    heat_demand_water  heat_demand_water_COM  heat_demand_water_MFH  \
# 0               45.0                   16.0                   20.0
# 1               52.0                   20.0                   21.0
# 2               50.0                   21.0                   20.0
# 3               57.0                   22.0                   20.0
# 4               98.0                   30.0                   31.0
#
#    heat_demand_water_SFH  heat_profile_space_COM  heat_profile_space_MFH  \
# 0                    9.0                   176.0                   128.0
# 1                   10.0                   179.0                   132.0
# 2                    9.0                   183.0                   135.0
# 3                   16.0                   196.0                   148.0
# 4                   37.0                   197.0                   173.0
#
#    heat_profile_space_SFH  heat_profile_water_COM  heat_profile_water_MFH  \
# 0                   143.0                    66.0                    68.0
# 1                   145.0                    83.0                    71.0
# 2                   150.0                    86.0                    68.0
# 3                   157.0                    88.0                    66.0
# 4                   177.0                   121.0                   105.0
#
#    heat_profile_water_SFH
# 0                    12.0
# 1                    15.0
# 2                    12.0
# 3                    22.0
# 4                    53.0
#
# [5 rows x 29 columns]

# %%
generic_column_names = ['COP_ASHP_floor', 'COP_ASHP_radiator', 'COP_ASHP_water',
                        'COP_GSHP_floor', 'COP_GSHP_radiator', 'COP_GSHP_water',
                        'COP_WSHP_floor', 'COP_WSHP_radiator', 'COP_WSHP_water',
                        'heat_demand_space', 'heat_demand_space_COM', 'heat_demand_space_MFH',
                        'heat_demand_space_SFH', 'heat_demand_total', 'heat_demand_water',
                        'heat_demand_water_COM', 'heat_demand_water_MFH', 'heat_demand_water_SFH',
                        'heat_profile_space_COM', 'heat_profile_space_MFH', 'heat_profile_space_SFH',
                        'heat_profile_water_COM', 'heat_profile_water_MFH', 'heat_profile_water_SFH']

country_codes = ['SE', 'EE', 'NO', 'DK', 'GR', 'IE', 'SK', 'PT', 'BE', 'SI', 'LU', 'IT', 'NL', 'HR', 'ES', 'CZ', 'AT', 'DE', 'HU', 'RO', 'LT', 'FR', 'BG', 'CH', 'FI', 'GB', 'LV', 'PL']

# %%
# Iterate through country DataFrames
for country_code, country_df in country_dfs.items():
    # Skip DataFrames with no 'heat_demand' columns
    if not any('heat_demand' in col for col in country_df.columns):
        print(f"Skipping {country_code} DataFrame as it has no 'heat_demand' columns.")
        continue

    print(f"Processing {country_code} DataFrame...")

    # Get the timestamp range for the current country DataFrame
    from_timestamp = "2016-02-01T00:30:00.000+05:30"
    till_timestamp = "2023-01-01T04:30:00.000+05:30"

    # Filter rows within the specified timestamp range
    selected_rows = country_df[(country_df['cet_cest_timestamp'] >= from_timestamp) & (country_df['cet_cest_timestamp'] <= till_timestamp)]

    # Identify rows with null or 0.0 values in the specified columns
    columns_to_check = ['heat_demand_space', 'heat_demand_space_COM', 'heat_demand_space_MFH',
                        'heat_demand_space_SFH', 'heat_demand_total', 'heat_demand_water',
                        'heat_demand_water_COM', 'heat_demand_water_MFH', 'heat_demand_water_SFH']

    rows_to_remove = selected_rows[selected_rows[columns_to_check].isnull().any(axis=1) | selected_rows[columns_to_check].eq(0.0).any(axis=1) | selected_rows[columns_to_check].eq('').any(axis=1)]

    # Remove identified rows from the country DataFrame
    country_df = country_df.drop(rows_to_remove.index)

    print(f"Finished processing {country_code} DataFrame.\n")

    # Update the country DataFrame in the dictionary
    country_dfs[country_code] = country_df
# Out:
# Processing HR DataFrame...
# Finished processing HR DataFrame.
#
# Processing DE DataFrame...
# Finished processing DE DataFrame.
#
# Skipping CH DataFrame as it has no 'heat_demand' columns.
# Processing GB DataFrame...
# Finished processing GB DataFrame.
#
# Processing BG DataFrame...
# Finished processing BG DataFrame.
#
# Processing DK DataFrame...
# Finished processing DK DataFrame.
#
# Processing FR DataFrame...
# Finished processing FR DataFrame.
#
# Processing BE DataFrame...
# Finished processing BE DataFrame.
#
# Processing ES DataFrame...
# Finished processing ES DataFrame.
#
# Skipping NO DataFrame as it has no 'heat_demand' columns.
# Processing FI DataFrame...
# Finished processing FI DataFrame.
#
# Processing LV DataFrame...
# Finished processing LV DataFrame.
#
# Processing RO DataFrame...
# Finished processing RO DataFrame.
#
# Processing PT DataFrame...
# Finished processing PT DataFrame.
#
# Processing LT DataFrame...
# Finished processing LT DataFrame.
#
# Processing CZ DataFrame...
# Finished processing CZ DataFrame.
#
# Processing PL DataFrame...
# Finished processing PL DataFrame.
#
# Processing SK DataFrame...
# Finished processing SK DataFrame.
#
# Processing IE DataFrame...
# Finished processing IE DataFrame.
#
# Processing GR DataFrame...
# Finished processing GR DataFrame.
#
# Processing SI DataFrame...
# Finished processing SI DataFrame.
#
# Processing NL DataFrame...
# Finished processing NL DataFrame.
#
# Processing LU DataFrame...
# Finished processing LU DataFrame.
#
# Processing AT DataFrame...
# Finished processing AT DataFrame.
#
# Processing SE DataFrame...
# Finished processing SE DataFrame.
#
# Processing HU DataFrame...
# Finished processing HU DataFrame.
#
# Processing IT DataFrame...
# Finished processing IT DataFrame.
#
# Processing EE DataFrame...
# Finished processing EE DataFrame.

# %%
# Iterate through country DataFrames
for country_code, country_df in country_dfs.items():
    # Skip DataFrames with no 'heat_demand' columns
    if not any('heat_demand' in col for col in country_df.columns):
        print(f"Skipping {country_code} DataFrame as it has no 'heat_demand' columns.")
        continue

    print(f"Processing {country_code} DataFrame...")

    # Get the timestamp range for the current country DataFrame
    from_timestamp = "2016-02-01T00:30:00.000+05:30"
    till_timestamp = "2023-01-01T04:30:00.000+05:30"

    # Filter rows within the specified timestamp range
    selected_rows = country_df[(country_df['cet_cest_timestamp'] >= from_timestamp) & (country_df['cet_cest_timestamp'] <= till_timestamp)]

    # Identify rows with null or 0.0 values in the specified columns
    columns_to_check = ['COP_ASHP_floor', 'COP_ASHP_radiator', 'COP_ASHP_water',
                        'COP_GSHP_floor', 'COP_GSHP_radiator', 'COP_GSHP_water',
                        'COP_WSHP_floor', 'COP_WSHP_radiator', 'COP_WSHP_water',
                        'heat_demand_space', 'heat_demand_space_COM', 'heat_demand_space_MFH',
                        'heat_demand_space_SFH', 'heat_demand_total', 'heat_demand_water',
                        'heat_demand_water_COM', 'heat_demand_water_MFH', 'heat_demand_water_SFH',
                        'heat_profile_space_COM', 'heat_profile_space_MFH', 'heat_profile_space_SFH',
                        'heat_profile_water_COM', 'heat_profile_water_MFH', 'heat_profile_water_SFH']

    rows_to_remove = selected_rows[selected_rows[columns_to_check].isnull().any(axis=1) | selected_rows[columns_to_check].eq(0.0).any(axis=1) | selected_rows[columns_to_check].eq('').any(axis=1)]

    # Remove identified rows from the country DataFrame
    country_df = country_df.drop(rows_to_remove.index)

    # Replace NaN values with the mean of each column
    country_df[columns_to_check] = country_df[columns_to_check].apply(lambda col: col.fillna(col.mean()))

    print(f"Finished processing {country_code} DataFrame.\n")

    # Update the country DataFrame in the dictionary
    country_dfs[country_code] = country_df
# Out:
# Processing HR DataFrame...
# Finished processing HR DataFrame.
#
# Processing DE DataFrame...
# Finished processing DE DataFrame.
#
# Skipping CH DataFrame as it has no 'heat_demand' columns.
# Processing GB DataFrame...
# Finished processing GB DataFrame.
#
# Processing BG DataFrame...
# Finished processing BG DataFrame.
#
# Processing DK DataFrame...
# Finished processing DK DataFrame.
#
# Processing FR DataFrame...
# Finished processing FR DataFrame.
#
# Processing BE DataFrame...
# Finished processing BE DataFrame.
#
# Processing ES DataFrame...
# Finished processing ES DataFrame.
#
# Skipping NO DataFrame as it has no 'heat_demand' columns.
# Processing FI DataFrame...
# Finished processing FI DataFrame.
#
# Processing LV DataFrame...
# Finished processing LV DataFrame.
#
# Processing RO DataFrame...
# Finished processing RO DataFrame.
#
# Processing PT DataFrame...
# Finished processing PT DataFrame.
#
# Processing LT DataFrame...
# Finished processing LT DataFrame.
#
# Processing CZ DataFrame...
# Finished processing CZ DataFrame.
#
# Processing PL DataFrame...
# Finished processing PL DataFrame.
#
# Processing SK DataFrame...
# Finished processing SK DataFrame.
#
# Processing IE DataFrame...
# Finished processing IE DataFrame.
#
# Processing GR DataFrame...
# Finished processing GR DataFrame.
#
# Processing SI DataFrame...
# Finished processing SI DataFrame.
#
# Processing NL DataFrame...
# Finished processing NL DataFrame.
#
# Processing LU DataFrame...
# Finished processing LU DataFrame.
#
# Processing AT DataFrame...
# Finished processing AT DataFrame.
#
# Processing SE DataFrame...
# Finished processing SE DataFrame.
#
# Processing HU DataFrame...
# Finished processing HU DataFrame.
#
# Processing IT DataFrame...
# Finished processing IT DataFrame.
#
# Processing EE DataFrame...
# Finished processing EE DataFrame.

# %%
# Iterate through country DataFrames
for country_code, country_df in country_dfs.items():
    print(f"Checking NaN values in {country_code} DataFrame...")

    # Check for NaN values in each column
    nan_values = country_df.isnull().sum()

    # Print the result
    print(f"NaN values in {country_code} DataFrame:")
    print(nan_values)

    print(f"Finished checking NaN values for {country_code} DataFrame.\n")
# Out:
# Checking NaN values in HR DataFrame...
# NaN values in HR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for HR DataFrame.
#
# Checking NaN values in DE DataFrame...
# NaN values in DE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for DE DataFrame.
#
# Checking NaN values in CH DataFrame...
# NaN values in CH DataFrame:
# cet_cest_timestamp             0
# year                           0
# month                          0
# day                            0
# hour                           0
# COP_ASHP_floor              1435
# COP_ASHP_radiator              3
# COP_ASHP_water             15871
# COP_GSHP_floor               743
# COP_GSHP_radiator              3
# COP_GSHP_water             38302
# COP_WSHP_floor              3678
# COP_WSHP_radiator              3
# COP_WSHP_water            131483
# heat_profile_space_COM         0
# heat_profile_space_MFH         0
# heat_profile_space_SFH         0
# heat_profile_water_COM         0
# heat_profile_water_MFH         0
# heat_profile_water_SFH         0
# dtype: int64
# Finished checking NaN values for CH DataFrame.
#
# Checking NaN values in GB DataFrame...
# NaN values in GB DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for GB DataFrame.
#
# Checking NaN values in BG DataFrame...
# NaN values in BG DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for BG DataFrame.
#
# Checking NaN values in DK DataFrame...
# NaN values in DK DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for DK DataFrame.
#
# Checking NaN values in FR DataFrame...
# NaN values in FR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for FR DataFrame.
#
# Checking NaN values in BE DataFrame...
# NaN values in BE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for BE DataFrame.
#
# Checking NaN values in ES DataFrame...
# NaN values in ES DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for ES DataFrame.
#
# Checking NaN values in NO DataFrame...
# NaN values in NO DataFrame:
# cet_cest_timestamp             0
# year                           0
# month                          0
# day                            0
# hour                           0
# COP_ASHP_floor              5014
# COP_ASHP_radiator           1459
# COP_ASHP_water             38617
# COP_GSHP_floor              2052
# COP_GSHP_radiator           1408
# COP_GSHP_water             60181
# COP_WSHP_floor             29015
# COP_WSHP_radiator            743
# COP_WSHP_water            131483
# heat_profile_space_COM         0
# heat_profile_space_MFH         0
# heat_profile_space_SFH         0
# heat_profile_water_COM         0
# heat_profile_water_MFH         0
# heat_profile_water_SFH         0
# dtype: int64
# Finished checking NaN values for NO DataFrame.
#
# Checking NaN values in FI DataFrame...
# NaN values in FI DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for FI DataFrame.
#
# Checking NaN values in LV DataFrame...
# NaN values in LV DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LV DataFrame.
#
# Checking NaN values in RO DataFrame...
# NaN values in RO DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for RO DataFrame.
#
# Checking NaN values in PT DataFrame...
# NaN values in PT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for PT DataFrame.
#
# Checking NaN values in LT DataFrame...
# NaN values in LT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LT DataFrame.
#
# Checking NaN values in CZ DataFrame...
# NaN values in CZ DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for CZ DataFrame.
#
# Checking NaN values in PL DataFrame...
# NaN values in PL DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for PL DataFrame.
#
# Checking NaN values in SK DataFrame...
# NaN values in SK DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SK DataFrame.
#
# Checking NaN values in IE DataFrame...
# NaN values in IE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for IE DataFrame.
#
# Checking NaN values in GR DataFrame...
# NaN values in GR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for GR DataFrame.
#
# Checking NaN values in SI DataFrame...
# NaN values in SI DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SI DataFrame.
#
# Checking NaN values in NL DataFrame...
# NaN values in NL DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for NL DataFrame.
#
# Checking NaN values in LU DataFrame...
# NaN values in LU DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LU DataFrame.
#
# Checking NaN values in AT DataFrame...
# NaN values in AT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for AT DataFrame.
#
# Checking NaN values in SE DataFrame...
# NaN values in SE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SE DataFrame.
#
# Checking NaN values in HU DataFrame...
# NaN values in HU DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for HU DataFrame.
#
# Checking NaN values in IT DataFrame...
# NaN values in IT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for IT DataFrame.
#
# Checking NaN values in EE DataFrame...
# NaN values in EE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor                0
# COP_ASHP_radiator             0
# COP_ASHP_water                0
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water                0
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            70861
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for EE DataFrame.

# %%
import pandas as pd

# Assuming df is your DataFrame and 'timestamp' is the column representing timestamps

# Step 1: Identify rows with NaN values
nan_rows = df[df.isnull().any(axis=1)]

# Step 2: Check timestamps
nan_rows['cet_cest_timestamp'] = pd.to_datetime(nan_rows['cet_cest_timestamp'])
current_year = pd.to_datetime('today').year

nan_rows = nan_rows[(nan_rows['cet_cest_timestamp'].dt.year >= (current_year - 2)) & (nan_rows['cet_cest_timestamp'].dt.year <= (current_year + 2))]

# Step 3: Replace NaN with mean of last 2 years and future 2 years
for col in nan_rows.columns:
    nan_rows[col].fillna(nan_rows[col].mean(), inplace=True)

# Step 4: Impute NaN values in previous years if needed
# Check and replace NaN values in the previous years

# Update the original DataFrame with the changes
df.update(nan_rows)

# Display the updated DataFrame
print(df)
# Out:
#                   cet_cest_timestamp  year  month  day  hour  COP_ASHP_floor  \
# 0      2008-01-01T03:30:00.000+05:30  2008      1    1     3             3.0
# 1      2008-01-01T04:30:00.000+05:30  2008      1    1     4             3.0
# 2      2008-01-01T05:30:00.000+05:30  2008      1    1     5             3.0
# 3      2008-01-01T06:30:00.000+05:30  2008      1    1     6             3.0
# 4      2008-01-01T07:30:00.000+05:30  2008      1    1     7             3.0
# ...                              ...   ...    ...  ...   ...             ...
# 77431  2016-10-31T19:30:00.000+05:30  2016     10   31    19             4.0
# 77432  2016-10-31T20:30:00.000+05:30  2016     10   31    20             4.0
# 77433  2016-10-31T21:30:00.000+05:30  2016     10   31    21             4.0
# 77434  2016-10-31T22:30:00.000+05:30  2016     10   31    22             4.0
# 77435  2016-10-31T23:30:00.000+05:30  2016     10   31    23             4.0
#
#        COP_ASHP_radiator  COP_ASHP_water  COP_GSHP_floor  COP_GSHP_radiator  \
# 0               2.833333             2.0             4.0                NaN
# 1               2.833333             2.0             4.0                NaN
# 2               2.833333             2.0             4.0                NaN
# 3               2.833333             2.0             4.0                NaN
# 4               2.833333             2.0             4.0                NaN
# ...                  ...             ...             ...                ...
# 77431           3.076923             NaN             5.0                4.0
# 77432           3.076923             NaN             5.0                4.0
# 77433           3.076923             NaN             5.0                4.0
# 77434           3.076923             2.0             5.0                4.0
# 77435           3.076923             2.0             5.0                4.0
#
#        ...  heat_demand_water  heat_demand_water_COM  heat_demand_water_MFH  \
# 0      ...               45.0                   16.0                   20.0
# 1      ...               52.0                   20.0                   21.0
# 2      ...               50.0                   21.0                   20.0
# 3      ...               57.0                   22.0                   20.0
# 4      ...               98.0                   30.0                   31.0
# ...    ...                ...                    ...                    ...
# 77431  ...              127.0                   26.5                   35.5
# 77432  ...              127.0                   26.5                   35.5
# 77433  ...              127.0                   26.5                   35.5
# 77434  ...              146.0                   27.0                   37.0
# 77435  ...              127.0                   26.5                   35.5
#
#        heat_demand_water_SFH  heat_profile_space_COM  heat_profile_space_MFH  \
# 0                        9.0                   176.0                   128.0
# 1                       10.0                   179.0                   132.0
# 2                        9.0                   183.0                   135.0
# 3                       16.0                   196.0                   148.0
# 4                       37.0                   197.0                   173.0
# ...                      ...                     ...                     ...
# 77431                   65.0                   151.0                   161.0
# 77432                   65.0                   152.0                   166.0
# 77433                   65.0                   151.0                   169.0
# 77434                   82.0                   142.0                   169.0
# 77435                   65.0                   133.0                   163.0
#
#        heat_profile_space_SFH  heat_profile_water_COM  heat_profile_water_MFH  \
# 0                       143.0                    66.0                    68.0
# 1                       145.0                    83.0                    71.0
# 2                       150.0                    86.0                    68.0
# 3                       157.0                    88.0                    66.0
# 4                       177.0                   121.0                   105.0
# ...                       ...                     ...                     ...
# 77431                   159.0                    83.0                   109.0
# 77432                   163.0                    86.0                   117.0
# 77433                   167.0                    89.0                   123.0
# 77434                   166.0                   105.0                   126.0
# 77435                   157.0                   114.0                   138.0
#
#        heat_profile_water_SFH
# 0                        12.0
# 1                        15.0
# 2                        12.0
# 3                        22.0
# 4                        53.0
# ...                       ...
# 77431                   118.0
# 77432                   139.0
# 77433                   134.0
# 77434                   141.0
# 77435                   146.0
#
# [72349 rows x 29 columns]

# %%
# Iterate through country DataFrames
for country_code, country_df in country_dfs.items():
    print(f"Checking NaN values in {country_code} DataFrame...")

    # Check for NaN values in each column
    nan_values = country_df.isnull().sum()

    # Print the result
    print(f"NaN values in {country_code} DataFrame:")
    print(nan_values)

    print(f"Finished checking NaN values for {country_code} DataFrame.\n")
# Out:
# Checking NaN values in HR DataFrame...
# NaN values in HR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            16158
# COP_ASHP_radiator          5904
# COP_ASHP_water             7949
# COP_GSHP_floor            16152
# COP_GSHP_radiator         11014
# COP_GSHP_water             5708
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for HR DataFrame.
#
# Checking NaN values in DE DataFrame...
# NaN values in DE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             5180
# COP_ASHP_radiator             0
# COP_ASHP_water            15923
# COP_GSHP_floor             4440
# COP_GSHP_radiator          1456
# COP_GSHP_water            17341
# COP_WSHP_floor             1480
# COP_WSHP_radiator           668
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for DE DataFrame.
#
# Checking NaN values in CH DataFrame...
# NaN values in CH DataFrame:
# cet_cest_timestamp             0
# year                           0
# month                          0
# day                            0
# hour                           0
# COP_ASHP_floor              1435
# COP_ASHP_radiator              3
# COP_ASHP_water             15871
# COP_GSHP_floor               743
# COP_GSHP_radiator              3
# COP_GSHP_water             38302
# COP_WSHP_floor              3678
# COP_WSHP_radiator              3
# COP_WSHP_water            131483
# heat_profile_space_COM         0
# heat_profile_space_MFH         0
# heat_profile_space_SFH         0
# heat_profile_water_COM         0
# heat_profile_water_MFH         0
# heat_profile_water_SFH         0
# dtype: int64
# Finished checking NaN values for CH DataFrame.
#
# Checking NaN values in GB DataFrame...
# NaN values in GB DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             4368
# COP_ASHP_radiator             0
# COP_ASHP_water            36258
# COP_GSHP_floor             2219
# COP_GSHP_radiator             0
# COP_GSHP_water            15902
# COP_WSHP_floor            10236
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for GB DataFrame.
#
# Checking NaN values in BG DataFrame...
# NaN values in BG DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             6638
# COP_ASHP_radiator             0
# COP_ASHP_water             5107
# COP_GSHP_floor             8842
# COP_GSHP_radiator          2220
# COP_GSHP_water            12325
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for BG DataFrame.
#
# Checking NaN values in DK DataFrame...
# NaN values in DK DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             9504
# COP_ASHP_radiator          1456
# COP_ASHP_water            29840
# COP_GSHP_floor             8860
# COP_GSHP_radiator           740
# COP_GSHP_water            24625
# COP_WSHP_floor             5802
# COP_WSHP_radiator          1336
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for DK DataFrame.
#
# Checking NaN values in FR DataFrame...
# NaN values in FR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor              740
# COP_ASHP_radiator             0
# COP_ASHP_water            23769
# COP_GSHP_floor             6662
# COP_GSHP_radiator          1480
# COP_GSHP_water             7112
# COP_WSHP_floor             2171
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for FR DataFrame.
#
# Checking NaN values in BE DataFrame...
# NaN values in BE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             7404
# COP_ASHP_radiator           740
# COP_ASHP_water            16652
# COP_GSHP_floor             9606
# COP_GSHP_radiator          3652
# COP_GSHP_water             7040
# COP_WSHP_floor              740
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for BE DataFrame.
#
# Checking NaN values in ES DataFrame...
# NaN values in ES DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             6666
# COP_ASHP_radiator             0
# COP_ASHP_water            21025
# COP_GSHP_floor            13974
# COP_GSHP_radiator          2936
# COP_GSHP_water                0
# COP_WSHP_floor             5060
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for ES DataFrame.
#
# Checking NaN values in NO DataFrame...
# NaN values in NO DataFrame:
# cet_cest_timestamp             0
# year                           0
# month                          0
# day                            0
# hour                           0
# COP_ASHP_floor              5014
# COP_ASHP_radiator           1459
# COP_ASHP_water             38617
# COP_GSHP_floor              2052
# COP_GSHP_radiator           1408
# COP_GSHP_water             60181
# COP_WSHP_floor             29015
# COP_WSHP_radiator            743
# COP_WSHP_water            131483
# heat_profile_space_COM         0
# heat_profile_space_MFH         0
# heat_profile_space_SFH         0
# heat_profile_water_COM         0
# heat_profile_water_MFH         0
# heat_profile_water_SFH         0
# dtype: int64
# Finished checking NaN values for NO DataFrame.
#
# Checking NaN values in FI DataFrame...
# NaN values in FI DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             2196
# COP_ASHP_radiator          2148
# COP_ASHP_water            13851
# COP_GSHP_floor             2220
# COP_GSHP_radiator          1384
# COP_GSHP_water            31910
# COP_WSHP_floor             6424
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for FI DataFrame.
#
# Checking NaN values in LV DataFrame...
# NaN values in LV DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            10872
# COP_ASHP_radiator          3634
# COP_ASHP_water            13845
# COP_GSHP_floor             8884
# COP_GSHP_radiator          4416
# COP_GSHP_water            26865
# COP_WSHP_floor             2816
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LV DataFrame.
#
# Checking NaN values in RO DataFrame...
# NaN values in RO DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             4444
# COP_ASHP_radiator             0
# COP_ASHP_water             4371
# COP_GSHP_floor             7362
# COP_GSHP_radiator             0
# COP_GSHP_water            16613
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for RO DataFrame.
#
# Checking NaN values in PT DataFrame...
# NaN values in PT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            17570
# COP_ASHP_radiator          2220
# COP_ASHP_water            17313
# COP_GSHP_floor            24844
# COP_GSHP_radiator         10298
# COP_GSHP_water              716
# COP_WSHP_floor             8617
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for PT DataFrame.
#
# Checking NaN values in LT DataFrame...
# NaN values in LT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             5180
# COP_ASHP_radiator          1480
# COP_ASHP_water             9449
# COP_GSHP_floor             5924
# COP_GSHP_radiator          1456
# COP_GSHP_water            21599
# COP_WSHP_floor             2219
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LT DataFrame.
#
# Checking NaN values in CZ DataFrame...
# NaN values in CZ DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             4440
# COP_ASHP_radiator             0
# COP_ASHP_water            10149
# COP_GSHP_floor             5930
# COP_GSHP_radiator             0
# COP_GSHP_water            19465
# COP_WSHP_floor             1456
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for CZ DataFrame.
#
# Checking NaN values in PL DataFrame...
# NaN values in PL DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             2962
# COP_ASHP_radiator             0
# COP_ASHP_water            10165
# COP_GSHP_floor             7402
# COP_GSHP_radiator          4440
# COP_GSHP_water            16669
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for PL DataFrame.
#
# Checking NaN values in SK DataFrame...
# NaN values in SK DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor              740
# COP_ASHP_radiator           740
# COP_ASHP_water             8717
# COP_GSHP_floor             1480
# COP_GSHP_radiator           740
# COP_GSHP_water            18821
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SK DataFrame.
#
# Checking NaN values in IE DataFrame...
# NaN values in IE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             2220
# COP_ASHP_radiator             0
# COP_ASHP_water            43595
# COP_GSHP_floor             2220
# COP_GSHP_radiator             0
# COP_GSHP_water            18130
# COP_WSHP_floor            13907
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for IE DataFrame.
#
# Checking NaN values in GR DataFrame...
# NaN values in GR DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            16182
# COP_ASHP_radiator          7402
# COP_ASHP_water            26247
# COP_GSHP_floor            18362
# COP_GSHP_radiator         13262
# COP_GSHP_water                0
# COP_WSHP_floor             2864
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for GR DataFrame.
#
# Checking NaN values in SI DataFrame...
# NaN values in SI DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            11062
# COP_ASHP_radiator           740
# COP_ASHP_water             7230
# COP_GSHP_floor             9578
# COP_GSHP_radiator          2912
# COP_GSHP_water            16577
# COP_WSHP_floor                0
# COP_WSHP_radiator           716
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SI DataFrame.
#
# Checking NaN values in NL DataFrame...
# NaN values in NL DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             6660
# COP_ASHP_radiator          2960
# COP_ASHP_water            19440
# COP_GSHP_floor            11066
# COP_GSHP_radiator          1456
# COP_GSHP_water             9951
# COP_WSHP_floor             3674
# COP_WSHP_radiator           668
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for NL DataFrame.
#
# Checking NaN values in LU DataFrame...
# NaN values in LU DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            12514
# COP_ASHP_radiator          2940
# COP_ASHP_water            11576
# COP_GSHP_floor             9550
# COP_GSHP_radiator          2936
# COP_GSHP_water            12204
# COP_WSHP_floor             1455
# COP_WSHP_radiator           716
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for LU DataFrame.
#
# Checking NaN values in AT DataFrame...
# NaN values in AT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             1456
# COP_ASHP_radiator             0
# COP_ASHP_water             5750
# COP_GSHP_floor                0
# COP_GSHP_radiator             0
# COP_GSHP_water            20241
# COP_WSHP_floor              740
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for AT DataFrame.
#
# Checking NaN values in SE DataFrame...
# NaN values in SE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             2148
# COP_ASHP_radiator             0
# COP_ASHP_water            17443
# COP_GSHP_floor             3604
# COP_GSHP_radiator          2148
# COP_GSHP_water            31970
# COP_WSHP_floor             3556
# COP_WSHP_radiator             0
# COP_WSHP_water            72349
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for SE DataFrame.
#
# Checking NaN values in HU DataFrame...
# NaN values in HU DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor            14670
# COP_ASHP_radiator          7380
# COP_ASHP_water             4419
# COP_GSHP_floor            17614
# COP_GSHP_radiator         10344
# COP_GSHP_water            13701
# COP_WSHP_floor                0
# COP_WSHP_radiator             0
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for HU DataFrame.
#
# Checking NaN values in IT DataFrame...
# NaN values in IT DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             4224
# COP_ASHP_radiator           716
# COP_ASHP_water            27569
# COP_GSHP_floor              740
# COP_GSHP_radiator             0
# COP_GSHP_water             2958
# COP_WSHP_floor             8713
# COP_WSHP_radiator           668
# COP_WSHP_water            72327
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for IT DataFrame.
#
# Checking NaN values in EE DataFrame...
# NaN values in EE DataFrame:
# cet_cest_timestamp            0
# year                          0
# month                         0
# day                           0
# hour                          0
# COP_ASHP_floor             8072
# COP_ASHP_radiator             0
# COP_ASHP_water            18219
# COP_GSHP_floor             8052
# COP_GSHP_radiator          2959
# COP_GSHP_water            31941
# COP_WSHP_floor             4991
# COP_WSHP_radiator           740
# COP_WSHP_water            72349
# heat_demand_space             0
# heat_demand_space_COM         0
# heat_demand_space_MFH         0
# heat_demand_space_SFH         0
# heat_demand_total             0
# heat_demand_water             0
# heat_demand_water_COM         0
# heat_demand_water_MFH         0
# heat_demand_water_SFH         0
# heat_profile_space_COM        0
# heat_profile_space_MFH        0
# heat_profile_space_SFH        0
# heat_profile_water_COM        0
# heat_profile_water_MFH        0
# heat_profile_water_SFH        0
# dtype: int64
# Finished checking NaN values for EE DataFrame.

# %%
import os
import pandas as pd

output_folder = "/Downloads/godsplan"

for country, df in country_dfs.items():
    # Save Pandas DataFrame to CSV in the specified folder
    csv_file_path = os.path.join(output_folder, f"{country}_preprocessed_data.csv")
    df.to_csv(csv_file_path, index=False)
